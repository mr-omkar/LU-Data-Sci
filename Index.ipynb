# %%
Q.1.  Ans:- B.RAINBOW

# %%
Q.2 Ans:-

# %%
str1="lets upgrade"
print(str1.upper())

# %%
Q.3 Ans:-

# %%
cp=int(input())
sp=int(input())
if(cp<0 or sp<0):
    print("Enter Valid Price")
elif(cp<sp):
    print("Profit")
elif(cp==sp):
    print("Neither")
else:
    print("Loss")

# %%
Q.4 Ans:-

# %%
indrup= int(input())
print(indrup*80)
